# %% [markdown]
# ## Using the simple Transformers for the fine tunning perpose of BERT model

# %%
! pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 61.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing the Train and the Test dataset for model

# %%
train = [
  {
    'context': 'The Eiffel Tower is located in Paris, France, and is one of the most recognizable structures in the world.',
    'qas': [
      {
        'id': '00001',
        'is_impossible': False,
        'question': 'Where is the Eiffel Tower located?',
        'answers': [
          {'text': 'Paris, France', 'answer_start': 28}
        ]
      },
      {
        'id': '00002',
        'is_impossible': True,
        'question': 'Is the Eiffel Tower located in New York?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Amazon rainforest is a vast tropical rainforest in South America that covers much of northwestern Brazil and extends into Colombia, Peru, and other South American countries.',
    'qas': [
      {
        'id': '00003',
        'is_impossible': False,
        'question': 'Which countries does the Amazon rainforest extend into?',
        'answers': [
          {'text': 'Colombia, Peru, and other South American countries', 'answer_start': 138}
        ]
      },
      {
        'id': '00004',
        'is_impossible': True,
        'question': 'Is the Amazon rainforest in Africa?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Great Wall of China is an ancient series of walls and fortifications, totaling more than 13,000 miles in length, located in northern China.',
    'qas': [
      {
        'id': '00005',
        'is_impossible': False,
        'question': 'How long is the Great Wall of China?',
        'answers': [
          {'text': 'more than 13,000 miles', 'answer_start': 73}
        ]
      },
      {
        'id': '00006',
        'is_impossible': True,
        'question': 'Is the Great Wall of China located in Japan?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Mona Lisa is a famous portrait painting by the Italian artist Leonardo da Vinci, housed in the Louvre Museum in Paris, France.',
    'qas': [
      {
        'id': '00007',
        'is_impossible': False,
        'question': 'Who painted the Mona Lisa?',
        'answers': [
          {'text': 'Leonardo da Vinci', 'answer_start': 57}
        ]
      },
      {
        'id': '00008',
        'is_impossible': True,
        'question': 'Is the Mona Lisa housed in the British Museum?',
        'answers': []
      }
    ]
  },
  {
    'context': 'Mount Everest, located in the Himalayas, is the highest mountain in the world, with a peak that reaches 29,032 feet above sea level.',
    'qas': [
      {
        'id': '00009',
        'is_impossible': False,
        'question': 'Where is Mount Everest located?',
        'answers': [
          {'text': 'Himalayas', 'answer_start': 29}
        ]
      },
      {
        'id': '00010',
        'is_impossible': True,
        'question': 'Is Mount Everest the highest mountain in the Andes?',
        'answers': []
      }
    ]
  },
  {
    'context': 'Albert Einstein was a theoretical physicist who developed the theory of relativity, one of the two pillars of modern physics.',
    'qas': [
      {
        'id': '00015',
        'is_impossible': False,
        'question': 'Who developed the theory of relativity?',
        'answers': [
          {'text': 'Albert Einstein', 'answer_start': 0}
        ]
      },
      {
        'id': '00016',
        'is_impossible': True,
        'question': 'Is Albert Einstein known for developing the quantum theory?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Pyramids of Giza, located in Egypt, are one of the Seven Wonders of the Ancient World and are the only one to remain largely intact.',
    'qas': [
      {
        'id': '00017',
        'is_impossible': False,
        'question': 'Where are the Pyramids of Giza located?',
        'answers': [
          {'text': 'Egypt', 'answer_start': 27}
        ]
      },
      {
        'id': '00018',
        'is_impossible': True,
        'question': 'Are the Pyramids of Giza located in Mexico?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Great Barrier Reef, located off the coast of Queensland, Australia, is the world\'s largest coral reef system.',
    'qas': [
      {
        'id': '00019',
        'is_impossible': False,
        'question': 'Where is the Great Barrier Reef located?',
        'answers': [
          {'text': 'off the coast of Queensland, Australia', 'answer_start': 28}
        ]
      },
      {
        'id': '00020',
        'is_impossible': True,
        'question': 'Is the Great Barrier Reef the largest mountain range in the world?',
        'answers': []
      }
    ]
  }
]

# %%
test = [
  {
    'context': 'The Statue of Liberty was a gift from France to the United States and is located on Liberty Island in New York Harbor.',
    'qas': [
      {
        'id': '00001',
        'is_impossible': False,
        'question': 'Who gifted the Statue of Liberty to the United States?',
        'answers': [
          {'text': 'France', 'answer_start': 34}
        ]
      },
      {
        'id': '00002',
        'is_impossible': True,
        'question': 'Is the Statue of Liberty located in California?',
        'answers': []
      }
    ]
  },
  {
    'context': 'The Pacific Ocean is the largest and deepest of Earth\'s oceanic divisions, extending from the Arctic Ocean in the north to the Southern Ocean in the south.',
    'qas': [
      {
        'id': '00003',
        'is_impossible': False,
        'question': 'What is the largest and deepest ocean?',
        'answers': [
          {'text': 'Pacific Ocean', 'answer_start': 4}
        ]
      },
      {
        'id': '00004',
        'is_impossible': True,
        'question': 'Does the Pacific Ocean extend from the Indian Ocean to the Atlantic Ocean?',
        'answers': []
      }
    ]
  }
]

# %% [markdown]
# ## Importing QuestionAnswerModel and QuestionAnswerArgs from simpletransformers:

# %%
import logging
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %% [markdown]
# ## Defining the model type and model name:

# %%
model_type = 'bert'
model_name = 'bert-base-cased'

# %% [markdown]
# ## Tunning\Setting Training parameters of model :

# %%
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 20,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %% [markdown]
# ## Defining model

# %%
model = QuestionAnsweringModel(model_type, model_name, train_args)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Training the model on train dataset and using test data for evaluation of model

# %%
model.train_model(train, eval_data = test)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# convert squad examples to features:   0%|          | 0/16 [00:00<?, ?it/s]Could not find answer: 'Peru, and other South American countries.' vs. 'Colombia, Peru, and other South American countries'
# Could not find answer: 'fortifications, totaling more than 13,000' vs. 'more than 13,000 miles'
# Could not find answer: 'Italian artist Leonardo' vs. 'Leonardo da Vinci'
# Could not find answer: 'located in' vs. 'Egypt'
# ...
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# ...

# %% [markdown]
# Above training logs are also generated in WandB

# %% [markdown]
# ## Lokking at results of the trained model based on the test data

# %%
result, texts = model.eval_model(test)
print(texts)
print(result)
# Out:
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]
# {'correct_text': {'00002': '', '00004': ''}, 'similar_text': {'00001': {'truth': 'France', 'predicted': '', 'question': 'Who gifted the Statue of Liberty to the United States?'}, '00003': {'truth': 'Pacific Ocean', 'predicted': '', 'question': 'What is the largest and deepest ocean?'}}, 'incorrect_text': {}}
# {'correct': 2, 'similar': 2, 'incorrect': 0, 'eval_loss': -0.65625}

# %% [markdown]
# ## Trying to answer one question using our trained model

# %%
# Make predictions with the model
to_predict = [
    {
        "context": "Vin is a Mistborn of great power and skill.",
        "qas": [
            {
                "question": "What is Vin's speciality?",
                "id": "0",
            }
        ],
    }
]

# %%
answers, probabilities = model.predict(to_predict)

print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['', 'Mistborn of great power and skill.']}]
